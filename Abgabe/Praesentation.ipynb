# %%
# Import aller benötigten Module

# Eigene Module
import DataGenerationRadar1D as gen_1D
from DataGenerationRadar3D import *
from DBScan import *
from ui import interactive1DExperiment, interactiveDBScan, interactive3DExperiment

# Externe Module
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import copy
from collections import deque
from ipywidgets import *
from collections import deque
# %matplotlib widget
plt.style.use('classic')

# %% [markdown]
# ## Das Kalamn-Filter

# %% [markdown]
# ### Interaktiver Plot

# %%
interactive1DExperiment.plot_interactive_kalaman_filter()
# Out:
# Output()
# Output()
# HBox(children=(VBox(children=(HTML(value='<h4>Data settings</h4>'), Dropdown(description='Type:', options=('St…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ## DB-Scan mit Kalman-Filter

# %% [markdown]
# ### Interaktiver Plot

# %%
interactive3DExperiment.plot_3DExperiment()
# Out:
# VBox(children=(FloatSlider(value=1.5, continuous_update=False, description='$\\epsilon$', max=3.0, min=0.1, re…
# Output()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
